# %%
def rotateString(s, goal):
  answer = False
  for chr in goal:
      if s[0]==chr:
          new_goal=goal[goal.index(chr):len(goal)]+goal[0:goal.index(chr)]
          if s==new_goal:
              answer = True
          else:
              answer = False
          break
  return answer
  pass
